# %%
import numpy as np
import pandas as pd
pd.set_option('max_colwidth', 150)
pd.set_option("display.max_rows",200)

# %%
input_file = '../models/train_2017-11-07_0400_percent.model.audit'
df_model = pd.read_csv(input_file, delimiter=':', header=None, names=['name', 'hash', 'value'])

# %%
df_model.sort_values('value').head(20)
# Out:
#                           name       hash    value
# 44                app^12*os^17  196654252 -1.39994
# 3393         app^3*channel^466  288876183 -1.32983
# 960          channel^489*os^13  154632478 -1.27751
# 1693          app^15*channel^3  117212915 -1.25715
# 2888              app^23*os^13   94988963 -1.24527
# 3894                    app^25  182682760 -1.16632
# 3899        app^25*channel^259  191635862 -1.16632
# 3898             app^25*app^25  113911440 -1.16632
# 3591               app^6*os^13  444840713 -1.15630
# 3900           app^25*device^1  174893633 -1.13912
# 5655        app^13*channel^469  231919217 -1.12755
# 3670                app^3*os^3  126888978 -1.10530
# 719               app^12*os^10  322034335 -1.09504
# 7559         channel^280*os^16  233338465 -1.06326
# 7737        app^17*channel^280  409078747 -1.05166
# 2977              app^14*os^18  238716088 -1.03044
# 2445               channel^212  253021086 -1.02234
# 2456   channel^212*channel^212  346571300 -1.02234
# 2457      channel^212*device^1  502890979 -1.02180
# 10502              app^12*os^6  151626987 -1.01696

# %%
df_model.sort_values('value', ascending=False).head(100)
# Out:
#                                                                                                                                                          name  \
# 5                                                                             PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps
# 8                                                                     PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels
# 31                                                           PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*device^1
# 28                                                                   PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*device^1
# 10      PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_att...
# 19      PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(c...
# 5083                                                              PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*channel^113
# 2244                                                      PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*channel^213
# 11      PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_...
# 12      PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_att...
# 2254                                                                                                                                  channel^213*channel^213
# 2236                                                                                                                                              channel^213
# 5086                                                      PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*channel^113
# 5097                                                                                                                                     channel^113*device^1
# 5078                                                                                                                                              channel^113
# 5096                                                                                                                                  channel^113*channel^113
# 13      PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is...
# 2241                                                              PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*channel^213
# 15821                                                     PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*channel^101
# 16      PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(cli...
# 5084                                                        PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*channel^113
# 18605                                                                                                                                       app^5*channel^113
# 2709                                                            PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^5
# 15818                                                                                                                                             channel^101
# 15826                                                                                                                                 channel^101*channel^101
# 6                                                                       PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices
# 15      PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks....
# 2255                                                                                                                                     channel^213*device^1
# 7                                                                             PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_attributed)_oses
# 15819                                                             PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*channel^101
# 2237                                                                   PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^29
# 5951                                                                   PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^19
# 18846                                                                                                                                                  app^35
# 18860                                                                                                                                           app^35*app^35
# 18848                                                                  PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^35
# 18862                                                                                                                                         app^35*device^1
# 2251                                                                                                                                          app^29*device^1
# 2249                                                                                                                                            app^29*app^29
# 2235                                                                                                                                                   app^29
# 26608                                                                                                                                    channel^101*device^1
# 5948                                                                                                                                                   app^19
# 5967                                                                                                                                            app^19*app^19
# 5952                                                             PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*app^19
# 2706                                                                    PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^5
# 5953                                                                   PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_attributed)_oses*app^19
# 2720                                                                                                                                           app^5*device^1
# 2718                                                                                                                                              app^5*app^5
# 2704                                                                                                                                                    app^5
# 2238                                                             PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*app^29
# 18851                                                          PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^35
# 5954                                                           PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^19
# 2240                                                           PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^29
# 5955                                                                 PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*device^0
# 18849                                                            PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*app^35
# 2707                                                              PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*app^5
# 181                                                                     PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*os^19
# 18861                                                                                                                                      app^35*channel^274
# 18852                                                             PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*channel^274
# 18865                                                                                                                                 channel^274*channel^274
# 18847                                                                                                                                             channel^274
# 18855                                                     PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*channel^274
# 18866                                                                                                                                    channel^274*device^1
# 5956                                                           PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*device^0
# 2242                                                        PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*channel^213
# 2239                                                                   PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_attributed)_oses*app^29
# 18850                                                                  PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_attributed)_oses*app^35
# 5079                                                                   PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^10
# 5082                                                           PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^10
# 14      PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clic...
# 279                                                                     PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*os^13
# 2243                                                              PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_attributed)_oses*channel^213
# 5975                                                                                                                                        device^0*device^0
# 5949                                                                                                                                                 device^0
# 5957                                                                 PERCENT_TRUE(clicks.is_attributed)_oses^PERCENT_TRUE(clicks.is_attributed)_oses*device^0
# 21130                                                          PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^45
# 184                                                             PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*os^19
# 5080                                                             PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*app^10
# 2250                                                                                                                                       app^29*channel^213
# 21127                                                                  PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^45
# 5093                                                                                                                                          app^10*device^1
# 5077                                                                                                                                                   app^10
# 5091                                                                                                                                            app^10*app^10
# 5092                                                                                                                                       app^10*channel^113
# 282                                                             PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*os^13
# 29                                                             PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*device^1
# 5958                                                         PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*device^0
# 21143                                                                                                                                         app^45*device^1
# 21124                                                                                                                                                  app^45
# 21141                                                                                                                                           app^45*app^45
# 5968                                                                                                                                       app^19*channel^213
# 18853                                                       PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*channel^274
# 130189                                                         PERCENT_TRUE(clicks.is_attributed)_channels^PERCENT_TRUE(clicks.is_attributed)_channels*app^72
# 130186                                                                 PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*app^72
# 130185                                                                                                                                                 app^72
# 130195                                                                                                                                     app^72*channel^101
# 130194                                                                                                                                          app^72*app^72
# 6449                                                                    PERCENT_TRUE(clicks.is_attributed)_apps^PERCENT_TRUE(clicks.is_attributed)_apps*os^24
# 130196                                                                                                                                        app^72*device^1
# 182                                                               PERCENT_TRUE(clicks.is_attributed)_devices^PERCENT_TRUE(clicks.is_attributed)_devices*os^19
# 5969                                                                                                                                          app^19*device^0
#
#              hash     value
# 5       361668269  0.542700
# 8        16171049  0.540228
# 31      188057810  0.489192
# 28      449233422  0.463979
# 10      151868666  0.371152
# 19      226902178  0.354790
