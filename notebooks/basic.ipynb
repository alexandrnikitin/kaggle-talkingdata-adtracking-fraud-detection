# %%
import numpy as np
import pandas as pd
import pandas_profiling
import datetime
import os
import time

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(12,5)});
plt.figure(figsize=(12,5));

# %%
dtypes = {
    'ip': 'uint32',
    'app': 'uint16',
    'device': 'uint16',
    'os': 'uint16',
    'channel': 'uint16',
    'is_attributed': 'uint8'
}
to_read = ['ip', 'app', 'device', 'os', 'channel', 'click_time', 'is_attributed']
to_parse = ['click_time']

# %%
train = pd.read_csv('../data/raw/train.csv', nrows=100000, usecols=to_read, dtype=dtypes, parse_dates=to_parse)
train.head()
# Out:
#        ip  app  device  os  channel          click_time  is_attributed
# 0   83230    3       1  13      379 2017-11-06 14:32:21              0
# 1   17357    3       1  19      379 2017-11-06 14:33:34              0
# 2   35810    3       1  13      379 2017-11-06 14:34:12              0
# 3   45745   14       1  13      478 2017-11-06 14:34:52              0
# 4  161007    3       1  13      379 2017-11-06 14:35:08              0

# %%
pandas_profiling.ProfileReport(train)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
to_read = ['ip', 'app', 'device', 'os', 'channel', 'click_time']
df_test = pd.read_csv('../data/raw/test.csv', usecols=to_read, dtype=dtypes, parse_dates=to_parse)

# %%
pandas_profiling.ProfileReport(df_test)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
