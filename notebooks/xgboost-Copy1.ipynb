# %%
import gc
import os
import operator

from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import xgbfir

from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from pandas.core.categorical import Categorical
from scipy.sparse import csr_matrix, hstack
from sklearn.metrics import roc_auc_score

# %%
dtypes = {
    'ip': 'uint32',
    'app': 'uint16',
    'device': 'uint16',
    'os': 'uint16',
    'channel': 'uint16',
    'is_attributed': 'uint8'
}

# Features used in training
categorical_features = ['app', 'device', 'os', 'channel']
numerical_features = [
    'PERCENT_TRUE(clicks.is_attributed)_app_1day', 'COUNT(clicks)_app_1day',
    'PERCENT_TRUE(clicks.is_attributed)_app_1hour',
    'COUNT(clicks)_app_1hour',
    'PERCENT_TRUE(clicks.is_attributed)_app_3hours',
    'COUNT(clicks)_app_3hours',
    'PERCENT_TRUE(clicks.is_attributed)_device_1day',
    'COUNT(clicks)_device_1day',
    'PERCENT_TRUE(clicks.is_attributed)_device_1hour',
    'COUNT(clicks)_device_1hour',
    'PERCENT_TRUE(clicks.is_attributed)_device_3hours',
    'COUNT(clicks)_device_3hours',
    'PERCENT_TRUE(clicks.is_attributed)_os_1day', 'COUNT(clicks)_os_1day',
    'PERCENT_TRUE(clicks.is_attributed)_os_1hour', 'COUNT(clicks)_os_1hour',
    'PERCENT_TRUE(clicks.is_attributed)_os_3hours',
    'COUNT(clicks)_os_3hours',
    'PERCENT_TRUE(clicks.is_attributed)_channel_1day',
    'COUNT(clicks)_channel_1day',
    'PERCENT_TRUE(clicks.is_attributed)_channel_1hour',
    'COUNT(clicks)_channel_1hour',
    'PERCENT_TRUE(clicks.is_attributed)_channel_3hours',
    'COUNT(clicks)_channel_3hours'
]


train_files = ['../data/processed/train_2017-11-08_1600.csv']

validation_files = ['../data/processed/test_2017-11-09_0600.csv']

# %%
def sparse_dummies(df, column):
    """Returns sparse OHE matrix for the column of the dataframe"""
    categories = Categorical(df[column])
    column_names = np.array([f"{column}_{str(i)}" for i in range(len(categories.categories))])
    N = len(categories)
    row_numbers = np.arange(N, dtype=np.int)
    ones = np.ones((N,))
    return csr_matrix((ones, (row_numbers, categories.codes))), column_names

# %%
df_train = pd.concat([pd.read_csv(f, dtype=dtypes) for f in train_files], ignore_index=True)
train_size = len(df_train)
print(f"train_size: {train_size}")
l_ = [df_train]
for f in validation_files:
    l_.append(pd.read_csv(f, dtype=dtypes))

df_train = pd.concat(l_, ignore_index=True)
# Out:
# train_size: 30313848

# %%
df_train.columns
# Out:
# Index(['app', 'device', 'os', 'channel', 'is_attributed',
#        'PERCENT_TRUE(clicks.is_attributed)_app_1day', 'COUNT(clicks)_app_1day',
#        'PERCENT_TRUE(clicks.is_attributed)_app_1hour',
#        'COUNT(clicks)_app_1hour',
#        'PERCENT_TRUE(clicks.is_attributed)_app_3hours',
#        'COUNT(clicks)_app_3hours',
#        'PERCENT_TRUE(clicks.is_attributed)_device_1day',
#        'COUNT(clicks)_device_1day',
#        'PERCENT_TRUE(clicks.is_attributed)_device_1hour',
#        'COUNT(clicks)_device_1hour',
#        'PERCENT_TRUE(clicks.is_attributed)_device_3hours',
#        'COUNT(clicks)_device_3hours',
#        'PERCENT_TRUE(clicks.is_attributed)_os_1day', 'COUNT(clicks)_os_1day',
#        'PERCENT_TRUE(clicks.is_attributed)_os_1hour', 'COUNT(clicks)_os_1hour',
#        'PERCENT_TRUE(clicks.is_attributed)_os_3hours',
#        'COUNT(clicks)_os_3hours',
#        'PERCENT_TRUE(clicks.is_attributed)_channel_1day',
#        'COUNT(clicks)_channel_1day',
#        'PERCENT_TRUE(clicks.is_attributed)_channel_1hour',
#        'COUNT(clicks)_channel_1hour',
#        'PERCENT_TRUE(clicks.is_attributed)_channel_3hours',
#        'COUNT(clicks)_channel_3hours'],
#       dtype='object')

# %%
matrices = []
all_column_names = []
# creates a matrix per categorical feature
for c in categorical_features:
    matrix, column_names = sparse_dummies(df_train, c)
    matrices.append(matrix)
    all_column_names.append(column_names)

# appends a matrix for numerical features (one column per feature)
matrices.append(csr_matrix(df_train[numerical_features].values, dtype=float))
all_column_names.append(df_train[numerical_features].columns.values)

train_sparse = hstack(matrices, format="csr")
feature_names = np.concatenate(all_column_names)
del matrices, all_column_names

X = train_sparse
y = df_train['is_attributed']

del df_train
gc.collect()
# Out:
# 19

# %%
# Create binary training and validation files for XGBoost
x1, y1 = X[:train_size], y.iloc[:train_size]
dm1 = xgb.DMatrix(x1, y1, feature_names=feature_names)
dm1.save_binary('../data/cache/train.bin')
del dm1, x1, y1
gc.collect()

x2, y2 = X[train_size:], y.iloc[train_size:]
dm2 = xgb.DMatrix(x2, y2, feature_names=feature_names)
dm2.save_binary('../data/cache/validate.bin')
del dm2, x2, y2, X, y
gc.collect()
# Out:
# 41

# %%
# XGBoost parameters example
params = {
    'eta': 0.3,
    'tree_method': "hist",
    'grow_policy': "lossguide",
    'max_leaves': 10000,  
    'max_depth': 0, 
    'subsample': 0.5, 
    'alpha':4,
    'objective': 'binary:logistic', 
    'scale_pos_weight':50,
    'eval_metric': 'auc', 
    'nthread':24,
    'silent': 1
}

# %%
dmtrain = xgb.DMatrix('../data/cache/train.bin', feature_names=feature_names)
dmvalid = xgb.DMatrix('../data/cache/validate.bin', feature_names=feature_names)

# %%
def objective(params):
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    watchlist = [(dmtrain, 'train'), (dmvalid, 'valid')]
    model = xgb.train(params, dmtrain, num_round, watchlist, maximize=True, early_stopping_rounds=20, verbose_eval=5)
    pred = model.predict(dmvalid, ntree_limit=model.best_ntree_limit)
    auc = roc_auc_score(dmvalid.get_label(), pred)
    del model, pred
    gc.collect()
    print(params)
    print(f"SCORE: {auc}")
    print("\n\n\n")
    return { 'loss': 1-auc, 'status': STATUS_OK }

space = {
    'n_estimators': hp.quniform('n_estimators', 200, 600, 50),
    'eta': hp.quniform('eta', 0.025, 0.25, 0.025),
    'max_depth': hp.choice('max_depth', np.arange(1, 14, dtype=int)),
    'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1),
    'subsample': hp.quniform('subsample', 0.7, 1, 0.05),
    'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.7, 1, 0.05),
    'alpha' : hp.quniform('alpha', 0, 10, 1),
    'lambda': hp.quniform('lambda', 1, 2, 0.1),
    'scale_pos_weight': hp.quniform('scale_pos_weight', 50, 200, 10),
    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'tree_method': "hist",
    'grow_policy': "lossguide",
    'booster': 'gbtree',
    'nthread': 24,
    'silent': 1
}

trials = Trials()
best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=100,
    trials=trials
)

print("\n\n\n The best hyperparameters:")
print(best)
# Out:
# [0]	train-auc:0.866869	valid-auc:0.884338
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.935923	valid-auc:0.933066
# [10]	train-auc:0.941264	valid-auc:0.933464
# [15]	train-auc:0.947676	valid-auc:0.93616
# [20]	train-auc:0.950397	valid-auc:0.93785
# [25]	train-auc:0.953062	valid-auc:0.939817
# [30]	train-auc:0.954569	valid-auc:0.940253
# [35]	train-auc:0.955557	valid-auc:0.940355
# [40]	train-auc:0.956972	valid-auc:0.940332
# [45]	train-auc:0.957779	valid-auc:0.940325
# [50]	train-auc:0.959248	valid-auc:0.940303
# [55]	train-auc:0.959611	valid-auc:0.939851
# [60]	train-auc:0.960216	valid-auc:0.939031
# Stopping. Best iteration:
# [42]	train-auc:0.957163	valid-auc:0.940942
#
# {'alpha': 3.0, 'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.25, 'eval_metric': 'auc', 'gamma': 0.7000000000000001, 'grow_policy': 'lossguide', 'lambda': 1.3, 'max_depth': 3, 'min_child_weight': 4.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 80.0, 'silent': 1, 'subsample': 0.8500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9409424903244744
#
#
#
#
# [0]	train-auc:0.950745	valid-auc:0.911833
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.953394	valid-auc:0.914832
# [10]	train-auc:0.958314	valid-auc:0.91477
# [15]	train-auc:0.961061	valid-auc:0.91945
# [20]	train-auc:0.96336	valid-auc:0.922275
# [25]	train-auc:0.965545	valid-auc:0.929527
# [30]	train-auc:0.967138	valid-auc:0.930118
# [35]	train-auc:0.968582	valid-auc:0.929478
# [40]	train-auc:0.969857	valid-auc:0.928312
# [45]	train-auc:0.971543	valid-auc:0.927969
# Stopping. Best iteration:
# [28]	train-auc:0.966368	valid-auc:0.931061
#
# {'alpha': 5.0, 'booster': 'gbtree', 'colsample_bytree': 1.0, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 0.9, 'grow_policy': 'lossguide', 'lambda': 1.1, 'max_depth': 11, 'min_child_weight': 3.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 140.0, 'silent': 1, 'subsample': 0.75, 'tree_method': 'hist'}
# SCORE: 0.9310608196332031
#
#
#
#
# [0]	train-auc:0.909094	valid-auc:0.922602
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.93435	valid-auc:0.928951
# [10]	train-auc:0.943736	valid-auc:0.93251
# [15]	train-auc:0.945056	valid-auc:0.933292
# [20]	train-auc:0.945117	valid-auc:0.933756
# [25]	train-auc:0.945099	valid-auc:0.933726
# [30]	train-auc:0.945587	valid-auc:0.934259
# [35]	train-auc:0.947706	valid-auc:0.934966
# [40]	train-auc:0.948828	valid-auc:0.935731
# [45]	train-auc:0.949295	valid-auc:0.93582
# [50]	train-auc:0.949682	valid-auc:0.935662
# [55]	train-auc:0.950099	valid-auc:0.93566
# [60]	train-auc:0.950443	valid-auc:0.936191
# [65]	train-auc:0.951081	valid-auc:0.936599
# [70]	train-auc:0.951272	valid-auc:0.93656
# [75]	train-auc:0.95189	valid-auc:0.936822
# [80]	train-auc:0.952621	valid-auc:0.937269
# [85]	train-auc:0.953043	valid-auc:0.937383
# [90]	train-auc:0.953778	valid-auc:0.938654
# [95]	train-auc:0.954229	valid-auc:0.938742
# [100]	train-auc:0.954909	valid-auc:0.938933
# [105]	train-auc:0.955777	valid-auc:0.939259
# [110]	train-auc:0.956354	valid-auc:0.939548
# [115]	train-auc:0.956675	valid-auc:0.939923
# [120]	train-auc:0.957024	valid-auc:0.939876
# [125]	train-auc:0.957689	valid-auc:0.940212
# [130]	train-auc:0.957966	valid-auc:0.940199
# [135]	train-auc:0.958351	valid-auc:0.940445
# [140]	train-auc:0.958781	valid-auc:0.94075
# [145]	train-auc:0.959235	valid-auc:0.941
# [150]	train-auc:0.959563	valid-auc:0.941266
# [155]	train-auc:0.960207	valid-auc:0.941249
# [160]	train-auc:0.960786	valid-auc:0.941429
# [165]	train-auc:0.961367	valid-auc:0.941374
# [170]	train-auc:0.961765	valid-auc:0.941455
# [175]	train-auc:0.962294	valid-auc:0.94161
# [180]	train-auc:0.962825	valid-auc:0.94173
# [200]	train-auc:0.963992	valid-auc:0.941727
# [205]	train-auc:0.964367	valid-auc:0.941742
# [210]	train-auc:0.964718	valid-auc:0.941753
# Stopping. Best iteration:
# [191]	train-auc:0.963599	valid-auc:0.9418
#
# {'alpha': 10.0, 'booster': 'gbtree', 'colsample_bytree': 0.7000000000000001, 'eta': 0.025, 'eval_metric': 'auc', 'gamma': 0.9, 'grow_policy': 'lossguide', 'lambda': 1.9000000000000001, 'max_depth': 6, 'min_child_weight': 9.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 60.0, 'silent': 1, 'subsample': 0.9500000000000001, 'tree_method': 'hist'}
# SCORE: 0.941799928937658
#
#
#
#
# [0]	train-auc:0.919933	valid-auc:0.91829
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.93332	valid-auc:0.924748
# [10]	train-auc:0.946429	valid-auc:0.933825
# [15]	train-auc:0.950813	valid-auc:0.936205
# [20]	train-auc:0.952383	valid-auc:0.938086
# [25]	train-auc:0.953129	valid-auc:0.93795
# [30]	train-auc:0.955933	valid-auc:0.938365
# [35]	train-auc:0.956866	valid-auc:0.939069
# [40]	train-auc:0.958368	valid-auc:0.940155
# [45]	train-auc:0.959773	valid-auc:0.94101
# [50]	train-auc:0.962065	valid-auc:0.941421
# [55]	train-auc:0.96338	valid-auc:0.941434
# [60]	train-auc:0.964166	valid-auc:0.941703
# [65]	train-auc:0.964824	valid-auc:0.941958
# [70]	train-auc:0.965319	valid-auc:0.941924
# [75]	train-auc:0.966072	valid-auc:0.941882
# [80]	train-auc:0.966509	valid-auc:0.941604
# [85]	train-auc:0.96686	valid-auc:0.941633
# Stopping. Best iteration:
# [66]	train-auc:0.965003	valid-auc:0.941961
#
# {'alpha': 2.0, 'booster': 'gbtree', 'colsample_bytree': 0.75, 'eta': 0.07500000000000001, 'eval_metric': 'auc', 'gamma': 0.8500000000000001, 'grow_policy': 'lossguide', 'lambda': 1.7000000000000002, 'max_depth': 6, 'min_child_weight': 1.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 100.0, 'silent': 1, 'subsample': 0.8, 'tree_method': 'hist'}
# SCORE: 0.9419610351099234
#
#
#
#
# [0]	train-auc:0.92233	valid-auc:0.917616
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.952179	valid-auc:0.931826
# [10]	train-auc:0.956641	valid-auc:0.936214
# [15]	train-auc:0.961274	valid-auc:0.934995
# [20]	train-auc:0.964367	valid-auc:0.934033
# [25]	train-auc:0.967447	valid-auc:0.93559
# [30]	train-auc:0.969083	valid-auc:0.927514
# Stopping. Best iteration:
# [13]	train-auc:0.960015	valid-auc:0.936869
#
# {'alpha': 8.0, 'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.75, 'grow_policy': 'lossguide', 'lambda': 1.1, 'max_depth': 7, 'min_child_weight': 2.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 130.0, 'silent': 1, 'subsample': 0.8500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9368685513799225
#
#
#
#
# [0]	train-auc:0.866859	valid-auc:0.884341
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.926912	valid-auc:0.932967
# [10]	train-auc:0.939051	valid-auc:0.934539
# [15]	train-auc:0.945992	valid-auc:0.936044
# [20]	train-auc:0.948972	valid-auc:0.938586
# [25]	train-auc:0.95121	valid-auc:0.938883
# [30]	train-auc:0.953064	valid-auc:0.939894
# [35]	train-auc:0.954631	valid-auc:0.940816
# [40]	train-auc:0.955876	valid-auc:0.941335
# [45]	train-auc:0.956558	valid-auc:0.941289
# [50]	train-auc:0.957997	valid-auc:0.941228
# [55]	train-auc:0.95851	valid-auc:0.941099
# [60]	train-auc:0.959232	valid-auc:0.940882
# Stopping. Best iteration:
# [42]	train-auc:0.956072	valid-auc:0.941491
#
# {'alpha': 1.0, 'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.55, 'grow_policy': 'lossguide', 'lambda': 1.4000000000000001, 'max_depth': 3, 'min_child_weight': 9.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 90.0, 'silent': 1, 'subsample': 0.9500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9414913265040035
#
#
#
#
# [0]	train-auc:0.94792	valid-auc:0.911471
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.954035	valid-auc:0.921671
# [10]	train-auc:0.955787	valid-auc:0.929369
# [15]	train-auc:0.957365	valid-auc:0.930291
# [20]	train-auc:0.959333	valid-auc:0.929557
# [25]	train-auc:0.961875	valid-auc:0.931708
# [30]	train-auc:0.962731	valid-auc:0.932211
# [35]	train-auc:0.96363	valid-auc:0.934375
# [40]	train-auc:0.965189	valid-auc:0.935494
# [45]	train-auc:0.966962	valid-auc:0.936216
# [50]	train-auc:0.969051	valid-auc:0.935132
# [55]	train-auc:0.970244	valid-auc:0.933764
# [60]	train-auc:0.971147	valid-auc:0.933114
# [65]	train-auc:0.971818	valid-auc:0.930558
# Stopping. Best iteration:
# [46]	train-auc:0.967144	valid-auc:0.936417
#
# {'alpha': 6.0, 'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.05, 'eval_metric': 'auc', 'gamma': 0.5, 'grow_policy': 'lossguide', 'lambda': 1.1, 'max_depth': 9, 'min_child_weight': 5.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 180.0, 'silent': 1, 'subsample': 0.9500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9364166355054073
#
#
#
#
# [0]	train-auc:0.851113	valid-auc:0.881034
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.863874	valid-auc:0.891949
# [10]	train-auc:0.892295	valid-auc:0.931693
# [15]	train-auc:0.925206	valid-auc:0.93531
# [20]	train-auc:0.934176	valid-auc:0.936369
# [25]	train-auc:0.937047	valid-auc:0.936369
# [30]	train-auc:0.940179	valid-auc:0.936375
# [35]	train-auc:0.941429	valid-auc:0.937331
# [40]	train-auc:0.944096	valid-auc:0.937035
# [45]	train-auc:0.944592	valid-auc:0.938398
# [50]	train-auc:0.944816	valid-auc:0.938475
# [55]	train-auc:0.944515	valid-auc:0.938563
# [60]	train-auc:0.945044	valid-auc:0.93874
# [65]	train-auc:0.946055	valid-auc:0.938911
# [70]	train-auc:0.946519	valid-auc:0.938766
# [75]	train-auc:0.947164	valid-auc:0.939234
# [80]	train-auc:0.94709	valid-auc:0.939259
# [85]	train-auc:0.947399	valid-auc:0.939256
# [90]	train-auc:0.948073	valid-auc:0.939269
# [95]	train-auc:0.948583	valid-auc:0.939091
# [100]	train-auc:0.94887	valid-auc:0.939224
# [105]	train-auc:0.949047	valid-auc:0.939355
# [110]	train-auc:0.949433	valid-auc:0.939089
# [115]	train-auc:0.949565	valid-auc:0.938984
# [120]	train-auc:0.949659	valid-auc:0.938855
# [125]	train-auc:0.94995	valid-auc:0.9391
# Stopping. Best iteration:
# [108]	train-auc:0.949307	valid-auc:0.939556
#
# {'alpha': 2.0, 'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.225, 'eval_metric': 'auc', 'gamma': 0.5, 'grow_policy': 'lossguide', 'lambda': 1.1, 'max_depth': 1, 'min_child_weight': 7.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 100.0, 'silent': 1, 'subsample': 0.9500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9395557118737754
#
#
#
#
# [0]	train-auc:0.851113	valid-auc:0.881034
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.864689	valid-auc:0.891804
# [10]	train-auc:0.880436	valid-auc:0.926281
# [15]	train-auc:0.910677	valid-auc:0.935406
# [20]	train-auc:0.924493	valid-auc:0.934306
# [25]	train-auc:0.930211	valid-auc:0.935299
# [30]	train-auc:0.932845	valid-auc:0.935952
# [35]	train-auc:0.936795	valid-auc:0.935342
# [40]	train-auc:0.939352	valid-auc:0.936234
# [45]	train-auc:0.940907	valid-auc:0.936006
# [50]	train-auc:0.941987	valid-auc:0.935796
# [55]	train-auc:0.942649	valid-auc:0.935786
# [60]	train-auc:0.942831	valid-auc:0.936913
# [65]	train-auc:0.943853	valid-auc:0.937887
# [70]	train-auc:0.944349	valid-auc:0.937962
# [75]	train-auc:0.944564	valid-auc:0.938346
# [80]	train-auc:0.944825	valid-auc:0.938758
# [85]	train-auc:0.94488	valid-auc:0.938687
# [90]	train-auc:0.945578	valid-auc:0.93861
# [95]	train-auc:0.945924	valid-auc:0.938604
# [100]	train-auc:0.945971	valid-auc:0.938595
# Stopping. Best iteration:
# [81]	train-auc:0.944829	valid-auc:0.938811
#
# {'alpha': 5.0, 'booster': 'gbtree', 'colsample_bytree': 0.8500000000000001, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.9, 'grow_policy': 'lossguide', 'lambda': 1.1, 'max_depth': 1, 'min_child_weight': 5.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 170.0, 'silent': 1, 'subsample': 0.7000000000000001, 'tree_method': 'hist'}
# SCORE: 0.9388111406436086
#
#
#
#
# [0]	train-auc:0.909852	valid-auc:0.918121
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.943448	valid-auc:0.93389
# [10]	train-auc:0.949383	valid-auc:0.936199
# [15]	train-auc:0.951918	valid-auc:0.93774
# [20]	train-auc:0.957079	valid-auc:0.938856
# [25]	train-auc:0.959963	valid-auc:0.940269
# [30]	train-auc:0.961276	valid-auc:0.940655
# [35]	train-auc:0.962325	valid-auc:0.940376
# [40]	train-auc:0.963961	valid-auc:0.939773
# [45]	train-auc:0.965365	valid-auc:0.939402
# Stopping. Best iteration:
# [28]	train-auc:0.960775	valid-auc:0.940708
#
# {'alpha': 5.0, 'booster': 'gbtree', 'colsample_bytree': 0.9500000000000001, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.9, 'grow_policy': 'lossguide', 'lambda': 1.7000000000000002, 'max_depth': 5, 'min_child_weight': 1.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 100.0, 'silent': 1, 'subsample': 0.9, 'tree_method': 'hist'}
# SCORE: 0.9407079594887457
#
#
#
#
# [0]	train-auc:0.851113	valid-auc:0.881034
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.863867	valid-auc:0.891862
# [10]	train-auc:0.881211	valid-auc:0.931537
# [20]	train-auc:0.931803	valid-auc:0.935658
# [25]	train-auc:0.936471	valid-auc:0.935909
# [30]	train-auc:0.939576	valid-auc:0.936649
# Stopping. Best iteration:
# [14]	train-auc:0.917751	valid-auc:0.936722
#
# {'alpha': 3.0, 'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.2, 'eval_metric': 'auc', 'gamma': 0.55, 'grow_policy': 'lossguide', 'lambda': 1.0, 'max_depth': 1, 'min_child_weight': 7.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 120.0, 'silent': 1, 'subsample': 0.8500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9367221213852541
#
#
#
#
# [0]	train-auc:0.851113	valid-auc:0.881034
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.863092	valid-auc:0.891649
# [10]	train-auc:0.864546	valid-auc:0.892678
# [15]	train-auc:0.892414	valid-auc:0.931062
# [20]	train-auc:0.919354	valid-auc:0.935144
# [25]	train-auc:0.925415	valid-auc:0.934328
# [30]	train-auc:0.93316	valid-auc:0.93538
# [35]	train-auc:0.93567	valid-auc:0.935576
# Stopping. Best iteration:
# [19]	train-auc:0.917525	valid-auc:0.936385
#
# {'alpha': 5.0, 'booster': 'gbtree', 'colsample_bytree': 0.9, 'eta': 0.15000000000000002, 'eval_metric': 'auc', 'gamma': 0.75, 'grow_policy': 'lossguide', 'lambda': 1.7000000000000002, 'max_depth': 1, 'min_child_weight': 8.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 100.0, 'silent': 1, 'subsample': 1.0, 'tree_method': 'hist'}
# SCORE: 0.9363846051426723
#
#
#
#
# [0]	train-auc:0.954611	valid-auc:0.853311
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.968126	valid-auc:0.915827
# [10]	train-auc:0.973229	valid-auc:0.920203
# [15]	train-auc:0.977629	valid-auc:0.914584
# [20]	train-auc:0.979913	valid-auc:0.908325
# [25]	train-auc:0.980892	valid-auc:0.905735
# [30]	train-auc:0.981179	valid-auc:0.904824
# Stopping. Best iteration:
# [12]	train-auc:0.975323	valid-auc:0.923885
#
# {'alpha': 1.0, 'booster': 'gbtree', 'colsample_bytree': 0.8, 'eta': 0.17500000000000002, 'eval_metric': 'auc', 'gamma': 0.9500000000000001, 'grow_policy': 'lossguide', 'lambda': 1.2000000000000002, 'max_depth': 13, 'min_child_weight': 4.0, 'nthread': 24, 'objective': 'binary:logistic', 'scale_pos_weight': 100.0, 'silent': 1, 'subsample': 0.8500000000000001, 'tree_method': 'hist'}
# SCORE: 0.9238852963815738
#
#
#
#
# [0]	train-auc:0.940686	valid-auc:0.863138
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 20 rounds.
# [5]	train-auc:0.95421	valid-auc:0.932013
# [10]	train-auc:0.954991	valid-auc:0.935107
# [15]	train-auc:0.957167	valid-auc:0.936065
# [20]	train-auc:0.957532	valid-auc:0.936975
# [25]	train-auc:0.957889	valid-auc:0.937133
# [30]	train-auc:0.958926	valid-auc:0.937605
# [35]	train-auc:0.959367	valid-auc:0.937831
# [40]	train-auc:0.96052	valid-auc:0.938268
# [45]	train-auc:0.961168	valid-auc:0.939291
# [50]	train-auc:0.9614	valid-auc:0.939164
# [55]	train-auc:0.962049	valid-auc:0.939865
# [60]	train-auc:0.962453	valid-auc:0.939671
# [65]	train-auc:0.96366	valid-auc:0.93934
# [70]	train-auc:0.964116	valid-auc:0.93943
# [75]	train-auc:0.964559	valid-auc:0.939381
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-c423701f867b> in <module>()
#      39     algo=tpe.suggest,
#      40     max_evals=100,
# ---> 41     trials=trials
#      42 )
#      43
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     305             verbose=verbose,
#     306             catch_eval_exceptions=catch_eval_exceptions,
# --> 307             return_argmin=return_argmin,
#     308         )
#     309
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin)
#     633             pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     634             catch_eval_exceptions=catch_eval_exceptions,
# --> 635             return_argmin=return_argmin)
#     636
#     637
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     318                     verbose=verbose)
#     319     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 320     rval.exhaust()
#     321     if return_argmin:
#     322         return trials.argmin
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/fmin.py in exhaust(self)
#     197     def exhaust(self):
#     198         n_done = len(self.trials)
# --> 199         self.run(self.max_evals - n_done, block_until_done=self.async)
#     200         self.trials.refresh()
#     201         return self
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     171             else:
#     172                 # -- loop over trials and do the jobs directly
# --> 173                 self.serial_evaluate()
#     174
#     175             if stopped:
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#      90                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#      91                 try:
# ---> 92                     result = self.domain.evaluate(spec, ctrl)
#      93                 except Exception as e:
#      94                     logger.info('job exception: %s' % str(e))
#
# /opt/conda/lib/python3.6/site-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     838                 memo=memo,
#     839                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 840             rval = self.fn(pyll_rval)
#     841
#     842         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-17-c423701f867b> in objective(params)
#       3     del params['n_estimators']
#       4     watchlist = [(dmtrain, 'train'), (dmvalid, 'valid')]
# ----> 5     model = xgb.train(params, dmtrain, num_round, watchlist, maximize=True, early_stopping_rounds=20, verbose_eval=5)
#       6     pred = model.predict(dmvalid, ntree_limit=model.best_ntree_limit)
#       7     auc = roc_auc_score(dmvalid.get_label(), pred)
#
# ~/xgboost/python-package/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# ~/xgboost/python-package/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~/xgboost/python-package/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     893         if fobj is None:
#     894             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# --> 895                                                     dtrain.handle))
#     896         else:
#     897             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
