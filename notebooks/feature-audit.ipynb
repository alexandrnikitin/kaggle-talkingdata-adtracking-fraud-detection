# %%
import numpy as np
import pandas as pd
pd.set_option('max_colwidth', 150)
pd.set_option("display.max_rows",200)

# %%
input_file = '../models/train_2017-11-07_0900_channel_features.model.audit'
df_model = pd.read_csv(input_file, delimiter=':', header=None, names=['name', 'hash', 'value'])

# %%
df_model.sort_values('value').head(20)
# Out:
#                                                      name       hash     value
# 2275                                    channel^113*os^19  391495785 -0.860608
# 447                          MODE(clicks.app)^12.0*app^12  310510926 -0.676950
# 4500                                    channel^113*os^13   53186058 -0.637416
# 448                        MODE(clicks.device)^1.0*app^12   84548075 -0.599210
# 434                                                app^12   10068776 -0.591873
# 463                                         app^12*app^12  423785680 -0.591873
# 457    NUM_UNIQUE(clicks.os)^NUM_UNIQUE(clicks.os)*app^12  258020886 -0.580401
# 449                           MODE(clicks.os)^19.0*app^12  362489364 -0.576416
# 465                                       app^12*device^1  530505633 -0.560457
# 1098              COUNT(clicks)^COUNT(clicks)*device^3032   18627583 -0.548408
# 1102                    MODE(clicks.os)^607.0*device^3032  529719524 -0.542822
# ...

# %%
df_model.sort_values('value', ascending=False).head(100)
# Out:
#                                                                                                                                               name  \
# 5                                                                            PERCENT_TRUE(clicks.is_attributed)^PERCENT_TRUE(clicks.is_attributed)
# 41                                                   MODE(clicks.device)^1.0*PERCENT_TRUE(clicks.is_attributed)^PERCENT_TRUE(clicks.is_attributed)
# 79                                                                  PERCENT_TRUE(clicks.is_attributed)^PERCENT_TRUE(clicks.is_attributed)*device^1
# 63                               NUM_UNIQUE(clicks.os)^NUM_UNIQUE(clicks.os)*PERCENT_TRUE(clicks.is_attributed)^PERCENT_TRUE(clicks.is_attributed)
# 76     PERCENT_TRUE(clicks.is_attributed)^PERCENT_TRUE(clicks.is_attributed)*PERCENT_TRUE(clicks.is_attributed)^PERCENT_TRUE(clicks.is_attributed)
# ...
