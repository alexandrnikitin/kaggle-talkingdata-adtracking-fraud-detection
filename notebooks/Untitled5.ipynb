# %%
import pickle
import pandas as pd

# %%
header = pickle.load(open("header.p", "rb"))
header
# Out:
# {'AVG_TIME_BETWEEN(clicks.click_time WHERE is_attributed = True)_app_7days': 'L',
#  'AVG_TIME_BETWEEN(clicks.click_time)_app_7days': 'K',
#  'MEDIAN(clicks.hour.AVG_TIME_BETWEEN(clicks.click_time))_app_7days': 'R',
#  'MEDIAN(clicks.hour.PERCENT_TRUE(clicks.is_attributed))_app_7days': 'Q',
#  'PERCENT_TRUE(clicks.is_attributed)_app_7days': 'J',
#  'SKEW(clicks.hour.AVG_TIME_BETWEEN(clicks.click_time))_app_7days': 'N',
#  'SKEW(clicks.hour.PERCENT_TRUE(clicks.is_attributed))_app_7days': 'M',
#  'STD(clicks.hour.AVG_TIME_BETWEEN(clicks.click_time))_app_7days': 'P',
#  'STD(clicks.hour.PERCENT_TRUE(clicks.is_attributed))_app_7days': 'O',
#  'app': 'B',
#  'attributed_time': 'G',
#  'channel': 'E',
#  'click_time': 'F',
#  'device': 'C',
#  'hour': 'I',
#  'ip': 'A',
#  'is_attributed': 'H',
#  'os': 'D'}

# %%
target_entities_init = ['app', 'device', 'os', 'channel', 'ip', 'hour']

interactions = [
    
]

# %%
df = pd.read_hdf("../data/interim/features/app/features_2017-11-10_1700_7days_countall.hdf.compress")

# %%
df
# Out:
#      COUNT(clicks)_app_7days  AVG_TIME_BETWEEN(clicks.click_time)_app_7days  \
# app
# 10                    864299                                       0.399861
# 138                      105                                    2581.923077
# 266                     6002                                      57.313948
# 394                     1313                                     236.218750
# 522                        1                                            NaN
# 650                        1                                            NaN
# 118                     1558                                     221.857418
# 246                      383                                     894.117801
# 374                        1                                            NaN
# 502                       26                                   13583.080000
# 630                        1                                            NaN
# ...

# %%
pd.read_csv('../data/interim/day_hour_train.csv')
# Out:
#     day  hour      start        end
# 0     6    14          0         47
# 1     6    15         48        482
# 2     6    16        483    2308259
# 3     6    17    2308260    3571607
# 4     6    18    3571608    4309747
# 5     6    19    4309748    4806101
# 6     6    20    4806102    5215853
# 7     6    21    5215854    5725425
# 8     6    22    5725426    6948955
# 9     6    23    6948956    9308567
# 10    7     0    9308568   12912932
# 11    7     1   12912933   16221082
# 12    7     2   16221083   19316715
# 13    7     3   19316716   22536986
# 14    7     4   22536987   26182479
# 15    7     5   26182480   29409828
# 16    7     6   29409829   32327112
# 17    7     7   32327113   35251145
# 18    7     8   35251146   38052438
# 19    7     9   38052439   41013757
# 20    7    10   41013758   44314503
# 21    7    11   44314504   47448703
# 22    7    12   47448704   50448794
# 23    7    13   50448795   53684033
# 24    7    14   53684034   56845830
# ...
